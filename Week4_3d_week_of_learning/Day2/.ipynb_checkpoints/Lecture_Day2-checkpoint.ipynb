# %%
import pandas as pd
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
flights = sns.load_dataset('flights')

# %%
type(flights)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Inspect Step

# %% [markdown]
# .columns
#
# .head()
#
# .tail()
#
# .info() # Data types of the columns, shows any missing values
#
# .describe() # Summary statistics

# %%
flights.columns
# Out:
# Index(['year', 'month', 'passengers'], dtype='object')

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights.tail()
# Out:
#      year month  passengers
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
flights.describe()
# Out:
#               year  passengers
# count   144.000000  144.000000
# mean   1954.500000  280.298611
# std       3.464102  119.966317
# min    1949.000000  104.000000
# 25%    1951.750000  180.000000
# 50%    1954.500000  265.500000
# 75%    1957.250000  360.500000
# max    1960.000000  622.000000

# %% [markdown]
# ### Select and Analyze Specific Columns

# %%
passengers = flights['passengers']

# %%
passengers.mean()
# Out:
# np.float64(280.2986111111111)

# %%
passengers.median()
# Out:
# np.float64(265.5)

# %%
passengers.min()
# Out:
# np.int64(104)

# %%
passengers.max()
# Out:
# np.int64(622)

# %%
passengers.sum()
# Out:
# np.int64(40363)

# %%
passengers.count()
# Out:
# np.int64(144)

# %%
passengers.std()
# Out:
# np.float64(119.9663169429432)

# %%
year_passengers = flights[['year', 'passengers']]

# %%
year_passengers.head()
# Out:
#    year  passengers
# 0  1949         112
# 1  1949         118
# 2  1949         132
# 3  1949         129
# 4  1949         121

# %% [markdown]
# ### Basic Filtering

# %%
high_traffic = flights[flights['passengers'] > 400]

# %%
mask = pd.Series([True] * 144) # creating the mask

# %%
flights['passengers'] > 400 # Boolean Mask

# %%
passengers_mask = flights ['passengers'] > 500

# %%
high_traffic[high_traffic['passengers'] == high_traffic['passengers'].max()]
# Out:
#      year month  passengers
# 138  1960   Jul         622

# %%
high_traffic['month'].value_counts().sort_index() # to sort by index
# Out:
# month
# Jan    1
# Feb    0
# Mar    2
# Apr    1
# May    2
# Jun    4
# Jul    5
# Aug    5
# Sep    4
# Oct    2
# Nov    0
# Dec    2
# Name: count, dtype: int64

# %%
flights.groupby('month')['passengers'].sum()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_39748\2940107518.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   flights.groupby('month')['passengers'].sum()
# month
# Jan    2901
# Feb    2820
# Mar    3242
# Apr    3205
# May    3262
# Jun    3740
# Jul    4216
# Aug    4213
# Sep    3629
# Oct    3199
# Nov    2794
# Dec    3142
# Name: passengers, dtype: int64

# %%
flights.groupby(['year','month'])['passengers'].sum()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_39748\3704443786.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   flights.groupby(['year','month'])['passengers'].sum()
# year  month
# 1949  Jan      112
#       Feb      118
#       Mar      132
#       Apr      129
#       May      121
#               ...
# 1960  Aug      606
#       Sep      508
#       Oct      461
#       Nov      390
#       Dec      432
# Name: passengers, Length: 144, dtype: int64

# %% [markdown]
# ### Advanced Filtering

# %%
flights['year'] >= 1955
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 139     True
# 140     True
# 141     True
# 142     True
# 143     True
# Name: year, Length: 144, dtype: bool

# %%
flights['month'] == 'Jul'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 139    False
# 140    False
# 141    False
# 142    False
# 143    False
# Name: month, Length: 144, dtype: bool

# %%
fifties_july_mask = flights[(flights['year'] >= 1955) & (flights['month'] == 'Jul')] # we can combine

# %%
flights[fifties_july_mask]
# Out:
#      year month  passengers
# 78   1955   Jul         364
# 90   1956   Jul         413
# 102  1957   Jul         465
# 114  1958   Jul         491
# 126  1959   Jul         548
# 138  1960   Jul         622

# %%
high_traffic_mask = flights['passengers'] > 500

# %%
summer_mask = (flights['month'] == 'Jun') | (flights['month'] == 'Jul') | (flights['month'] == 'Aug')   # 'or' operator

# %%
high_traffic_summer_mask = (flights['passengers'] > 500) & ((flights['month'] == 'Jun') | (flights['month'] == 'Jul') | (flights['month'] == 'Aug'))

# %%
flights[high_traffic_summer_mask]
# Out:
#      year month  passengers
# 115  1958   Aug         505
# 126  1959   Jul         548
# 127  1959   Aug         559
# 137  1960   Jun         535
# 138  1960   Jul         622
# 139  1960   Aug         606

# %% [markdown]
# #### Better way : Using .isin() for multiple values

# %%
summer_month = ['Jun', 'Jul', 'Aug']

# %%
summer_month_mask = (flights['month'].isin(summer_month)) & (flights['passengers'] > 500)

# %%
flights [summer_month_mask]
# Out:
#      year month  passengers
# 115  1958   Aug         505
# 126  1959   Jul         548
# 127  1959   Aug         559
# 137  1960   Jun         535
# 138  1960   Jul         622
# 139  1960   Aug         606

# %% [markdown]
# #### Using .between() for Ranges

# %%
# (flights['passengers'] > 300) & (flights['passengers'] < 400)
moderate_traffic_mask = flights['passengers'].between(300,400)

# %%
flights[moderate_traffic_mask]
# Out:
#      year month  passengers
# 66   1954   Jul         302
# 77   1955   Jun         315
# 78   1955   Jul         364
# 79   1955   Aug         347
# 80   1955   Sep         312
# 86   1956   Mar         317
# 87   1956   Apr         313
# 88   1956   May         318
# 89   1956   Jun         374
# 92   1956   Sep         355
# 93   1956   Oct         306
# 95   1956   Dec         306
# 96   1957   Jan         315
# 97   1957   Feb         301
# 98   1957   Mar         356
# 99   1957   Apr         348
# 100  1957   May         355
# 105  1957   Oct         347
# 106  1957   Nov         305
# 107  1957   Dec         336
# 108  1958   Jan         340
# 109  1958   Feb         318
# 110  1958   Mar         362
# 111  1958   Apr         348
# 112  1958   May         363
# 117  1958   Oct         359
# 118  1958   Nov         310
# 119  1958   Dec         337
# 120  1959   Jan         360
# 121  1959   Feb         342
# 123  1959   Apr         396
# 130  1959   Nov         362
# 133  1960   Feb         391
# 142  1960   Nov         390

# %%
years = [1955, 1956, 1957]
fifties_moderate_year = (flights['passengers'].between(300,400)) & (flights['year'].isin(years))

# %%
flights[fifties_moderate_year]
# Out:
#      year month  passengers
# 77   1955   Jun         315
# 78   1955   Jul         364
# 79   1955   Aug         347
# 80   1955   Sep         312
# 86   1956   Mar         317
# 87   1956   Apr         313
# 88   1956   May         318
# 89   1956   Jun         374
# 92   1956   Sep         355
# 93   1956   Oct         306
# 95   1956   Dec         306
# 96   1957   Jan         315
# 97   1957   Feb         301
# 98   1957   Mar         356
# 99   1957   Apr         348
# 100  1957   May         355
# 105  1957   Oct         347
# 106  1957   Nov         305
# 107  1957   Dec         336

# %% [markdown]
# ### Inverting Conditions With~

# %%
summer_month = ['Jun', 'Jul', 'Aug'] 
non_summer_mask = ~flights['month'].isin(summer_month) # reverse True to False

# %%
flights[non_summer_mask]
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 136  1960   May         472
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [108 rows x 3 columns]

# %%
passengers_mask = flights['passengers'].between(100,200) 
year_mask = flights['year'].between(1950,1960)

# %%
passengers_year_mask = (passengers_mask) & (year_mask)

# %%
len(flights[passengers_year_mask])
# Out:
# 36

# %%
month_list = ['Dec', 'Jan']

after_1955_mask = flights['year'] > 1955
jan_dec_mask = flights['month'].isin(month_list)

# %%
flights[(after_1955_mask) & (jan_dec_mask)]
# Out:
#      year month  passengers
# 84   1956   Jan         284
# 95   1956   Dec         306
# 96   1957   Jan         315
# 107  1957   Dec         336
# 108  1958   Jan         340
# 119  1958   Dec         337
# 120  1959   Jan         360
# 131  1959   Dec         405
# 132  1960   Jan         417
# 143  1960   Dec         432

# %%
high_traffic_mask = flights['passengers'] > 600

# %%
flights[high_traffic_mask]['year'].unique()
# Out:
# array([1960])

# %% [markdown]
# ### Sorting
# #### Top/buttom performers identification
# ##### Trends over time
# ###### Identifying Ouiliers

# %%
flights_sorted = flights.sort_values('passengers') # sorts the data in ascending order (small to high)

# %%
flights_sorted
# Out:
#      year month  passengers
# 10   1949   Nov         104
# 0    1949   Jan         112
# 22   1950   Nov         114
# 12   1950   Jan         115
# 11   1949   Dec         118
# ..    ...   ...         ...
# 137  1960   Jun         535
# 126  1959   Jul         548
# 127  1959   Aug         559
# 139  1960   Aug         606
# 138  1960   Jul         622
#
# [144 rows x 3 columns]

# %%
flights.sort_values(by = ['year', 'passengers'], ascending=[False,True]) #year = False, passengers = True
# Out:
#      year month  passengers
# 142  1960   Nov         390
# 133  1960   Feb         391
# 132  1960   Jan         417
# 134  1960   Mar         419
# 143  1960   Dec         432
# ..    ...   ...         ...
# 2    1949   Mar         132
# 5    1949   Jun         135
# 8    1949   Sep         136
# 6    1949   Jul         148
# 7    1949   Aug         148
#
# [144 rows x 3 columns]

# %% [markdown]
# ### nlargest, nsmallest

# %%
flights.nlargest(10, 'passengers')
# Out:
#      year month  passengers
# 138  1960   Jul         622
# 139  1960   Aug         606
# 127  1959   Aug         559
# 126  1959   Jul         548
# 137  1960   Jun         535
# 140  1960   Sep         508
# 115  1958   Aug         505
# 114  1958   Jul         491
# 125  1959   Jun         472
# 136  1960   May         472

# %%
flights.nsmallest(10, 'passengers')
# Out:
#     year month  passengers
# 10  1949   Nov         104
# 0   1949   Jan         112
# 22  1950   Nov         114
# 12  1950   Jan         115
# 1   1949   Feb         118
# 11  1949   Dec         118
# 9   1949   Oct         119
# 4   1949   May         121
# 16  1950   May         125
# 13  1950   Feb         126
